# %%
import pandas as  pd


df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2   Bonnell, Miss Elizabeth   58  female

# %%
df['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages = pd.Series([22,35,38], name='Age')
ages
# Out:
# 0    22
# 1    35
# 2    38
# Name: Age, dtype: int64

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 881          882         0       3                       Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss Gerda Ulrika
# 883          884         0       2            Banfield, Mr. Frederick James
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
ages = df['Age']
ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
type(df['Age'])
# Out:
# pandas.Series

# %%
df.shape
# Out:
# (891, 12)

# %%
age_sex = df[['Age', 'Sex']]

age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
age_sex.shape
# Out:
# (891, 2)

# %%
above_35 =  df[df['Age'] >  35] 
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
above_35.shape
# Out:
# (217, 12)

# %%
class_23 = df[df['Pclass'].isin((2,3))]
class_23
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss Laina
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 7              8         0       3            Palsson, Master Gosta Leonard
# ..           ...       ...     ...                                      ...
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 890          891         0       3                      Dooley, Mr. Patrick
#
# ...

# %%
class_23 = df[(df["Pclass"] == 2) | (df["Pclass"] == 3)]
class_23
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss Laina
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 7              8         0       3            Palsson, Master Gosta Leonard
# ..           ...       ...     ...                                      ...
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 890          891         0       3                      Dooley, Mr. Patrick
#
# ...

# %%
age_no_na = df[df['Age'].notna()]
age_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
adult_names = df.loc[df['Age'] > 35, 'Name']
adult_names
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                                McCarthy, Mr. Timothy J
# 11                               Bonnell, Miss Elizabeth
# 13                           Andersson, Mr. Anders Johan
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 865                             Bystrom, Mrs. (Karolina)
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: str

# %%
df.iloc[9:25, 2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                     Sandstrom, Miss Marguerite Rut  female
# 11       1                            Bonnell, Miss Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3                Vestrom, Miss Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                                Rice, Master Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
df.iloc[0:3, 3] = "anonymous"

df.iloc[:5, 3]
# Out:
# 0                                       anonymous
# 1                                       anonymous
# 2                                       anonymous
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: str

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("air_quality_no2.csv", index_col=0, parse_dates=True)
air_quality
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
air_quality.plot()
plt.show()

# %%
air_quality['station_paris'].plot()
plt.show()

# %%
air_quality.plot.scatter(x='station_london', y='station_paris', alpha=0.5)

plt.show()

# %%
air_quality.plot.box()

plt.show()

# %%
axs = air_quality.plot.area(figsize=(12,4), subplots=True)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(12,4))
air_quality.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration")
fig.savefig("no2_concentrations.png")
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                       anonymous    male  22.0      1      0
# 1                                       anonymous  female  38.0      1      0
# 2                                       anonymous  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %%
air_quality['london_mg_per_cubic'] = air_quality['station_london'] * 1.882
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
air_quality['ratio_paris_antwerp'] = air_quality['station_paris'] / air_quality['station_antwerp']
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "station_antwerp": "BETR801",
        "station_paris" : "FR04014",
        "station_london" : "London Westminster",
    }
)
air_quality_renamed.head()
# Out:
#                      BETR801  FR04014  London Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv"
titanic = pd.read_csv(url)

# %%
titanic['Age'].mean
# Out:
# <bound method Series.mean of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
titanic[['Age', 'Fare']].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[['Age', 'Fare']].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic.agg({
    'Age': ["min", "max", "median", "skew"],
    'Fare': ["min", "max", "median", "mean"],
    }
)
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %%
titanic[['Sex', 'Age']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby('Sex').mean(numeric_only=True)
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
titanic.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby(['Sex', 'Pclass'])['Fare'].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
air_quality = pd.read_csv(
    "air_quality_long.csv", index_col="date.utc", parse_dates=True
)
air_quality.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
titanic.sort_values(by='Age').head()
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 803          804         1       3  Thomas, Master Assad Alexander    male
# 755          756         1       2        Hamalainen, Master Viljo    male
# 644          645         1       3           Baclini, Miss Eugenie  female
# 469          470         1       3    Baclini, Miss Helene Barbara  female
# 78            79         1       2    Caldwell, Master Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
titanic.sort_values(by=['Pclass', 'Age'], ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
no2 = air_quality[air_quality["parameter"] == "no2"]
no2
# Out:
#                              city country            location parameter  \
# date.utc
# 2019-06-21 00:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 23:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 22:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 21:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 20:00:00+00:00   Paris      FR             FR04014       no2
# ...                           ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-06-21 00:00:00+00:00   20.0  µg/m³
# ...

# %%
no2_subset  = no2.sort_index().groupby(['location']).head(2)
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-04-09 01:00:00+00:00   22.5  µg/m³
# 2019-04-09 01:00:00+00:00   24.4  µg/m³
# 2019-04-09 02:00:00+00:00   67.0  µg/m³
# 2019-04-09 02:00:00+00:00   53.5  µg/m³
# 2019-04-09 02:00:00+00:00   27.4  µg/m³
# 2019-04-09 03:00:00+00:00   67.0  µg/m³

# %%
no2_subset.pivot(columns='location', values='value')
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2019-04-09 03:00:00+00:00      NaN      NaN                67.0

# %%
no2.pivot(columns='location', values='value').plot()
# Out:
# <Axes: xlabel='date.utc'>

# %%
air_quality.pivot_table(
    values='value', index='location', columns='parameter', aggfunc='mean'
)
# Out:
# parameter                 no2       pm25
# location
# BETR801             26.950920  23.169492
# FR04014             29.374284        NaN
# London Westminster  29.740050  13.443568

# %%
air_quality.pivot_table(
    values="value",
    index="location",
    columns="parameter",
    aggfunc="mean",
    margins=True,
)
# Out:
# parameter                 no2       pm25        All
# location
# BETR801             26.950920  23.169492  24.982353
# FR04014             29.374284        NaN  29.374284
# London Westminster  29.740050  13.443568  21.491708
# All                 29.430316  14.386849  24.222743

# %%
no2_pivoted = no2.pivot(columns='location', values='value').reset_index()
no2_pivoted.head()
# Out:
# location                  date.utc  BETR801  FR04014  London Westminster
# 0        2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 1        2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2        2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 3        2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 4        2019-04-09 05:00:00+00:00     46.5     59.5                41.0

# %%
no_2 = no2_pivoted.melt(id_vars="date.utc")
no_2.head()
# Out:
#                    date.utc location  value
# 0 2019-04-09 01:00:00+00:00  BETR801   22.5
# 1 2019-04-09 02:00:00+00:00  BETR801   53.5
# 2 2019-04-09 03:00:00+00:00  BETR801   54.5
# 3 2019-04-09 04:00:00+00:00  BETR801   34.5
# 4 2019-04-09 05:00:00+00:00  BETR801   46.5

# %%
no_2 = no2_pivoted.melt(
    id_vars="date.utc",
    value_vars=["BETR801", "FR04014", "London Westminster"],
    value_name="NO_2",
    var_name="id_location"
)

no_2.head()
# Out:
#                    date.utc id_location  NO_2
# 0 2019-04-09 01:00:00+00:00     BETR801  22.5
# 1 2019-04-09 02:00:00+00:00     BETR801  53.5
# 2 2019-04-09 03:00:00+00:00     BETR801  54.5
# 3 2019-04-09 04:00:00+00:00     BETR801  34.5
# 4 2019-04-09 05:00:00+00:00     BETR801  46.5

# %%
import pandas as pd
df = pd.DataFrame({
    'Name': ['Alice', 'John', 'Kate'],
    'Score': [88, 95, 72],
    'Passed': [True, True, False],
},
    index=['s1', 's2', 's3']
                 )
print(f'Размерность: {df.shape}')
print('\nТипы данных:')
print(df.dtypes)
# Out:
# Размерность: (3, 3)
#
# Типы данных:
# Name        str
# Score     int64
# Passed     bool
# dtype: object

# %%
print(df.loc['s1'])
# Out:
# Name      Alice
# Score        88
# Passed     True
# Name: s1, dtype: object

# %%
print(df.iloc[0])
# Out:
# Name      Alice
# Score        88
# Passed     True
# Name: s1, dtype: object

# %%
print(df.loc['s2', 'Score'])
# Out:
# 95

# %%
print(df.loc['s1':'s2'])
# Out:
#      Name  Score  Passed
# s1  Alice     88    True
# s2   John     95    True

# %%
print(df.iloc[0:2])
# Out:
#      Name  Score  Passed
# s1  Alice     88    True
# s2   John     95    True

# %%
print(df.loc[['s1','s3'], 'Score'])
# Out:
# s1    88
# s3    72
# Name: Score, dtype: int64

# %%
print(df.iloc[2])
# Out:
# Name       Kate
# Score        72
# Passed    False
# Name: s3, dtype: object

# %%
df.loc['s3', 'Score'] = 80
df.loc['s3', 'Score']
# Out:
# np.int64(80)

# %%
mask = df['Score'] > 80
filtered_df = df[mask]


filtered_df
# Out:
#      Name  Score  Passed
# s1  Alice     88    True
# s2   John     95    True

# %%
df[(df['Score'] > 80) | (df['Passed'] == True)]
# Out:
#      Name  Score  Passed
# s1  Alice     88    True
# s2   John     95    True

# %%
df[df['Name'].isin(['Anna', 'Kate'])]
# Out:
#     Name  Score  Passed
# s3  Kate     80   False

# %%
df.query('Score > 80 and Passed == True')
# Out:
#      Name  Score  Passed
# s1  Alice     88    True
# s2   John     95    True

# %%
df.query('Score >= 80')
# Out:
#      Name  Score  Passed
# s1  Alice     88    True
# s2   John     95    True
# s3   Kate     80   False

# %%
df[(df['Score'] >= 80) & (df['Passed'] == False)]
# Out:
#     Name  Score  Passed
# s3  Kate     80   False

# %%
import numpy as np
df['Age'] = [20, np.nan, 22]

df_new =  df.assign(Score_Double=df['Score'] * 2)
df
# Out:
#      Name  Score  Passed   Age
# s1  Alice     88    True  20.0
# s2   John     95    True   NaN
# s3   Kate     80   False  22.0

# %%
mean_age = df['Age'].mean()
df['Age'] = df['Age'].fillna(mean_age)
df
# Out:
#      Name  Score  Passed   Age
# s1  Alice     88    True  20.0
# s2   John     95    True  21.0
# s3   Kate     80   False  22.0

# %%
medi_age = df['Age'].median()
df['Age'] = df['Age'].fillna(medi_age)
df
# Out:
#      Name  Score  Passed   Age
# s1  Alice     88    True  20.0
# s2   John     95    True  21.0
# s3   Kate     80   False  22.0

# %%
df.groupby('Passed')['Score'].mean()
# Out:
# Passed
# False    80.0
# True     91.5
# Name: Score, dtype: float64

# %%
df.groupby('Passed')['Name'].count()
# Out:
# Passed
# False    1
# True     2
# Name: Name, dtype: int64

# %%
df.groupby('Passed')['Score'].agg(['mean', 'max', 'min', 'count'])
# Out:
#         mean  max  min  count
# Passed
# False   80.0   80   80      1
# True    91.5   95   88      2

# %%
df.groupby('Passed').agg({
    'Score': 'mean',
    'Age' : 'max',
})
# Out:
#         Score   Age
# Passed
# False    80.0  22.0
# True     91.5  21.0

# %%
df.groupby('Passed', as_index=False)['Score'].mean()
# Out:
#    Passed  Score
# 0   False   80.0
# 1    True   91.5

# %%
df['Group'] = ['A','A','B']
df
# Out:
#      Name  Score  Passed   Age Group
# s1  Alice     88    True  20.0     A
# s2   John     95    True  21.0     A
# s3   Kate     80   False  22.0     B

# %%
df.groupby('Group')['Score'].mean()
# Out:
# Group
# A    91.5
# B    80.0
# Name: Score, dtype: float64

# %%
df.groupby('Group')['Age'].agg(['min', 'max'])
# Out:
#         min   max
# Group
# A      20.0  21.0
# B      22.0  22.0

# %%
df_groups = pd.DataFrame({
    'Group': ['A', 'B', 'C'],
    'Mentor': ['Dr. Smith', 'Prof. Jones', 'Dr. Adams']
})

# %%
merged_df = pd.merge(df, df_groups, on='Group', how='left')
merged_df
# Out:
#     Name  Score  Passed   Age Group       Mentor
# 0  Alice     88    True  20.0     A    Dr. Smith
# 1   John     95    True  21.0     A    Dr. Smith
# 2   Kate     80   False  22.0     B  Prof. Jones

# %%
df_city = pd.DataFrame({
    'Name': ['Alice', 'John', 'Kate'],
    'City': ['Kyiv', 'Lviv', 'Odesa']
})

# %%
merged_df = pd.merge(df, df_city, on='Name', how='left')
merged_df
# Out:
#     Name  Score  Passed   Age Group   City
# 0  Alice     88    True  20.0     A   Kyiv
# 1   John     95    True  21.0     A   Lviv
# 2   Kate     80   False  22.0     B  Odesa

# %%
df = pd.DataFrame(
    {
        'Name': ['Alice', 'John', 'Kate'],
        'Score': [88, 80, 80],
        'Passed': [True, True, False],
        'Age': [20.0, 21.0, 22.0],
        'Group': ['A', 'A', 'B'],
    },
    index=['s1', 's2', 's3'],
)


df_city = pd.DataFrame(
    {'Name': ['Alice', 'John', 'Kate'], 'City': ['Kyiv', 'Lviv', 'Odesa']}
)


merged_df = pd.merge(df, df_city, on='Name', how='left')
merged_df
# Out:
#     Name  Score  Passed   Age Group   City
# 0  Alice     88    True  20.0     A   Kyiv
# 1   John     80    True  21.0     A   Lviv
# 2   Kate     80   False  22.0     B  Odesa

# %%
sorted_df = (
    merged_df.sort_values(by='Score', ascending=False).reset_index(drop=True)
)
sorted_df
# Out:
#     Name  Score  Passed   Age Group   City
# 0  Alice     88    True  20.0     A   Kyiv
# 1   John     80    True  21.0     A   Lviv
# 2   Kate     80   False  22.0     B  Odesa

# %%
merged_df['Status'] = merged_df['Score'].apply(
    lambda x: 'Excellent' if x >= 85 else 'Good'
)
merged_df
# Out:
#     Name  Score  Passed   Age Group   City     Status
# 0  Alice     88    True  20.0     A   Kyiv  Excellent
# 1   John     80    True  21.0     A   Lviv       Good
# 2   Kate     80   False  22.0     B  Odesa       Good

# %%
def check_grant(row):
    if row['Score'] >= 85 and row['Passed']:
        return 'Scholarship Granted'
    return 'No Scholarship'

merged_df['Grant'] =  merged_df.apply(check_grant, axis=1)
merged_df
# Out:
#     Name  Score  Passed   Age Group   City     Status                Grant
# 0  Alice     88    True  20.0     A   Kyiv  Excellent  Scholarship Granted
# 1   John     80    True  21.0     A   Lviv       Good       No Scholarship
# 2   Kate     80   False  22.0     B  Odesa       Good       No Scholarship

# %%
merged_df['Age_Group'] = merged_df['Age'].apply(
    lambda x: 'Junior' if x < 21 else 'Senior'
)

def get_summary_row(row):
    return f"{row['Name']} from {row['City']}"
    
merged_df['Summary'] = merged_df.apply(get_summary_row, axis=1)
merged_df
# Out:
#     Name  Score  Passed   Age Group   City     Status                Grant  \
# 0  Alice     88    True  20.0     A   Kyiv  Excellent  Scholarship Granted
# 1   John     80    True  21.0     A   Lviv       Good       No Scholarship
# 2   Kate     80   False  22.0     B  Odesa       Good       No Scholarship
#
#   Age_Group          Summary
# 0    Junior  Alice from Kyiv
# 1    Senior   John from Lviv
# 2    Senior  Kate from Odesa

# %%
merged_df.to_csv('students.csv')

# %%
df_loaded = pd.read_csv('students.csv')
df_loaded
# Out:
#    Unnamed: 0   Name  Score  Passed   Age Group   City     Status  \
# 0           0  Alice     88    True  20.0     A   Kyiv  Excellent
# 1           1   John     80    True  21.0     A   Lviv       Good
# 2           2   Kate     80   False  22.0     B  Odesa       Good
#
#                  Grant Age_Group          Summary
# 0  Scholarship Granted    Junior  Alice from Kyiv
# 1       No Scholarship    Senior   John from Lviv
# 2       No Scholarship    Senior  Kate from Odesa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
plt.bar(merged_df['Name'], merged_df['Score'], color='skyblue')
plt.title('Scores by Student')
plt.xlabel('Student Name')
plt.ylabel('Score')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
sns.barplot(data=merged_df, x='Group', y='Score', hue='Passed')
plt.title('Score by Group and Passed status')
plt.show()

# %%
sns.scatterplot(data=merged_df, x='Age', y='Score', hue='Group')
plt.title('Score by Group and Passed status')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

df_titanic = pd.read_csv(url)

df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
df_titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df_titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df_titanic.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df_titanic.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
numeric_df = df_titanic.select_dtypes(include=['number'])

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
df_titanic['Title'] = df_titanic['Name'].str.extract(
    r' ([A-Za-z]+)\.', expand=False
)
df_titanic['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Don           1
# Mme           1
# Ms            1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
#Synonims and rare categories in title col in a Rare state
df_titanic['Title']  = df_titanic['Title'].replace(
    ['Mlle', 'Ms'], 'Miss'
)
df_titanic['Title'] = df_titanic['Title'].replace('Mme', 'Mrs')


rare_titles = [
    'Lady',
    'Countess',
    'Capt',
    'Col',
    'Don',
    'Dr',
    'Major',
    'Rev',
    'Sir',
    'Jonkheer',
    'Dona',
]
df_titanic['Title'] = df_titanic['Title'].replace(rare_titles, 'Rare')

df_titanic['Title']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886    Rare
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: str

# %%
#Percentage of  survival by a title
df_titanic.groupby('Title')['Survived'].mean()
# Out:
# Title
# Master    0.575000
# Miss      0.702703
# Mr        0.156673
# Mrs       0.793651
# Rare      0.347826
# Name: Survived, dtype: float64

# %%
#Deletinga a blanks
df_titanic['Age'] = df_titanic['Age'].fillna(
    df_titanic.groupby('Title')['Age'].transform('median')
)
df_titanic['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
#Creating a new signs FamiliSize and IsAlone
df_titanic['FamilySize'] = df_titanic['SibSp'] + df_titanic['Parch'] + 1

df_titanic['IsAlone']  =  (df_titanic['FamilySize'] == 1).astype(int)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#One hot encoding
df_titanic_encoded = pd.get_dummies(
    df_titanic, columns=['Sex', 'Embarked', 'Title'], drop_first=True
)

# %%
drop_cols = ['PassengerId', 'Name', 'Ticket', 'Cabin']
df_final =  df_titanic_encoded.drop(columns=drop_cols)
df_final.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  FamilySize  IsAlone  \
# 0         0       3  22.0      1      0   7.2500           2        0
# 1         1       1  38.0      1      0  71.2833           2        0
# 2         1       3  26.0      0      0   7.9250           1        1
# 3         1       1  35.0      1      0  53.1000           2        0
# 4         0       3  35.0      0      0   8.0500           1        1
#
#    Sex_male  Embarked_Q  Embarked_S  Title_Miss  Title_Mr  Title_Mrs  \
# 0      True       False        True       False      True      False
# 1     False       False       False       False     False       True
# 2     False       False        True        True     False      False
# 3     False       False        True       False     False       True
# 4      True       False        True       False      True      False
#
#    Title_Rare
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

X = df_final.drop(columns=['Survived'])
y = df_final['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train,  y_train)

y_pred = model.predict(X_test)

print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Accuracy: 0.7982

# %%
#Importances
pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
# Out:
# Fare          0.239803
# Age           0.207945
# Sex_male      0.123723
# Title_Mr      0.123123
# Pclass        0.084970
# FamilySize    0.051386
# Title_Miss    0.038955
# SibSp         0.030810
# Title_Mrs     0.024019
# Parch         0.022243
# Embarked_S    0.021844
# IsAlone       0.011394
# Embarked_Q    0.011318
# Title_Rare    0.008466
# dtype: float64

# %%
#creating a confusion matrix to check  accurancy of model
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))

plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       139
#            1       0.74      0.71      0.73        84
#
#     accuracy                           0.80       223
#    macro avg       0.79      0.78      0.78       223
# weighted avg       0.80      0.80      0.80       223
